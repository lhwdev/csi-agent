# %%
# !lerobot-teleoperate \
    --robot.type=so101_follower \
    --robot.port=/dev/ttyACM0 \
    --robot.id=lhwdev_follower3 \
    --teleop.type=so101_leader \
    --teleop.port=/dev/ttyACM1 \
    --teleop.id=lhwdev_leader

# %%
# !lerobot-teleoperate \
    --robot.type=so101_follower \
    --robot.port=/dev/ttyACM0 \
    --robot.id=lhwdev_follower3 \
    --robot.cameras='{front: {type: opencv, index_or_path: 2, width: 640, height: 480, fps: 30}}' \
    --teleop.type=so101_leader \
    --teleop.port=/dev/ttyACM1 \
    --teleop.id=lhwdev_leader \
    --fps=100 --display_data=true

# %%
# !lerobot-teleoperate \
    --robot.type=so101_follower \
    --robot.port=/dev/ttyACM0 \
    --robot.id=lhwdev_follower3 \
    --robot.cameras='{front: {type: opencv, index_or_path: 2, width: 640, height: 480, fps: 30}}' \
    --teleop.type=so101_leader \
    --teleop.port=/dev/ttyACM1 \
    --teleop.id=lhwdev_leader \
    --display_data=true \
    --dataset.push_to_hub=false \
    --dataset.root='lhwdev/records/pick_umbrella' \
    --dataset.num_episodes=30 \
    --dataset.episode_time_s=40 --dataset.reset_time_s=10 \
    --dataset.streaming_encoding=true \
    --dataset.single_task="Pick up the umbrella."
